# %% [markdown]
# #### Save Silver layer in (delta format)

# %%
silver_path = "abfss://silver@stamazonreviewdldev.dfs.core.windows.net/silver_data"

df_silver.write \
    .format("delta") \
    .mode("overwrite") \
    .save(silver_path)
