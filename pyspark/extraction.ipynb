# %% [markdown]
# # Silver Layer Script

# %%
spark.conf.set(
    "fs.azure.account.auth.type.customerreviewdatalake.dfs.core.windows.net",
    "OAuth"
)
spark.conf.set(
    "fs.azure.account.oauth.provider.type.customerreviewdatalake.dfs.core.windows.net",
    "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider"
)
spark.conf.set(
    "fs.azure.account.oauth2.client.id.customerreviewdatalake.dfs.core.windows.net",
    "439c4141-f42c-472d-8525-ab443f9b4d29"
)
spark.conf.set(
    "fs.azure.account.oauth2.client.secret.customerreviewdatalake.dfs.core.windows.net",
    "aAr8Q~mc5Pb5dFhZI-Yg9qqKf.y5LzLeI.fQ3a4m"
)
spark.conf.set(
    "fs.azure.account.oauth2.client.endpoint.customerreviewdatalake.dfs.core.windows.net",
    "https://login.microsoftonline.com/53a18eb4-fd3a-4238-a082-07b7bd65cb8b/oauth2/token"
)

# %% [markdown]
# ### Connection Testing

# %%
display(
    dbutils.fs.ls(
        "abfss://bronze@customerreviewdatalake.dfs.core.windows.net/"
    )
)

# %% [markdown]
# ### Reading Data

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .option("multiLine", "true") \
    .option("quote", '"') \
    .option("escape", '"') \
    .option("mode", "PERMISSIVE") \
    .load("abfss://bronze@customerreviewdatalake.dfs.core.windows.net/raw_data")
