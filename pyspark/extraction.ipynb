# %% [markdown]
# # SILVER LAYER SCRIPT

# %%
spark.conf.set(
    "fs.azure.account.auth.type.stamazonreviewdldev.dfs.core.windows.net",
    "OAuth"
)
spark.conf.set(
    "fs.azure.account.oauth.provider.type.stamazonreviewdldev.dfs.core.windows.net",
    "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider"
)
spark.conf.set(
    "fs.azure.account.oauth2.client.id.stamazonreviewdldev.dfs.core.windows.net",
    " c8e635a1-a1dc-4e6b-bcaa-eeec4a694acb"
)
spark.conf.set(
    "fs.azure.account.oauth2.client.secret.stamazonreviewdldev.dfs.core.windows.net",
    "w6g8Q~1YF6Uo.bunYE2HkiOioWszRQI6MdvibaGB"
)
spark.conf.set(
    "fs.azure.account.oauth2.client.endpoint.stamazonreviewdldev.dfs.core.windows.net",
    "https://login.microsoftonline.com/05d0a268-e403-4164-9126-d88560bb6dad/oauth2/token"
)

# %% [markdown]
# #### Connection Testing

# %% [markdown]
# display(
#     dbutils.fs.ls(
#         "abfss://bronze@stamazonreviewdldev.dfs.core.windows.net/"
#     )
# )

# %% [markdown]
# #### Read the Data

# %% [markdown]
# df = spark.read \
#     .format("csv") \
#     .option("header", "true") \
#     .option("multiline", "true") \
#     .option("quote", '"') \
#     .option("escape", '"') \
#     .option("mode", 'PERMISSIVE') \
#     .load("abfss://bronze@stamazonreviewdldev.dfs.core.windows.net/raw_data")
